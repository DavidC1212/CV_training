# %% [markdown]
# # PS0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
img1 = cv2.imread(r'C:\Users\sus85\OneDrive\Desktop\CV\cv_David\CV_training\computer_vision\course_resources\ps_0\woman.tiff')
img2 = cv2.imread(r'C:\Users\sus85\OneDrive\Desktop\CV\cv_David\CV_training\computer_vision\course_resources\ps_0\lena.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)
plt.show()

# %%
new_img = np.zeros(img1.shape, dtype=np.uint8)
new_img[:, :, 1] = img1[:, :, 1]
plt.imshow(new_img)
plt.show()

# %%
new_img_r = np.zeros(img1.shape, dtype=np.uint8)
new_img_r[:, :, 0] = img1[:, :, 0]
plt.imshow(new_img_r)
plt.show()

# %% [markdown]
# Which looks more like what you’d expect a monochrome image to look like? Would you expect a computer vision algorithm to work on one better than the other?
#
# same(?)

# %% [markdown]
# # 3

# %%
H,W,C = new_img.shape

# %%
new_img_2 = np.zeros(img2.shape, dtype=np.uint8)
new_img_2[:, :, 1] = img2[:, :, 1]
H2,W2,C2 = new_img_2.shape
plt.imshow(new_img_2)
plt.show()

# %%
new_img_2[int(H2/2 - 50):int(H2/2 + 50), int(W2/2 - 50): int(W2/2 + 50), :] = new_img[int(H/2 - 50):int(H/2 + 50), int(W/2 - 50): int(W/2 + 50), :]

# %%
plt.imshow(new_img_2)
plt.show()

# %% [markdown]
# # 4

# %%
img1_green = new_img

# %%
print("min " + str(np.min(img1_green)) + "\nmax "+ str(np.max(img1_green)) + "\nmean "+ str(np.mean(img1_green))+ "\nstd "+ str(np.std(img1_green)))
# Out:
# min 0
# max 212
# mean 32.92903363133248
# std 54.36746168160183

# %%
img_normalized = (img1_green - np.mean(img1_green)) / np.std(img1_green)

# %%
new_img = (img_normalized * 10) + np.mean(img1_green)
new_img = new_img.astype(int)

# %%
plt.imshow(new_img)

# %%
shifted_img1 = np.zeros(img1_green.shape)
shifted_img1[:, :-2] = img1_green[:, 2:]
shifted_img1 = shifted_img1.astype(int)

# %%
plt.imshow(shifted_img1)

# %%
plt.imshow(img1_green - shifted_img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 5

# %%
sigma = 30
noise = np.random.normal(0, 1, img1_green.shape) * sigma

plt.imshow((img1 + noise).astype(int))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img1_blue = np.zeros(img1.shape)
img1_blue[:,:,2] = img1[:,:,2]

# %%
plt.imshow(img1_blue.astype(int))

# %%
sigma = 4
noise = np.random.normal(0, 1, img1_blue.shape) * sigma

# %%
plt.imshow((img1_blue+ noise).astype(int))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# The first looks better since here we adding noise to the other channles as well
